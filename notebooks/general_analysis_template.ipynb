# %% [markdown]
# # Título del notebook

# %% [markdown]
# <b><span style="color: #0099d8;">Fecha creación:</span></b> <br>
# <b><span style="color: #0099d8;">Fecha última modificación:</span></b> <br>
# <b><span style="color: #0099d8;">Contribuidores:</span></b> <br>
# <br>
# <b><span style="color: #0099d8;">Descripción:</span></b> <br>
# <br>
# <b><span style="color: #0099d8;">Input:</span></b> <br>
# <b><span style="color: #0099d8;">Output:</span></b><br>
#
# <b><span style="font-size: 26px;">Tabla de contenidos:</span></b>
# <ul>
#     <li><a href="#">1. Resumen ejecutivo</a></li>
#     <ul>
#         <li><a href="#">1.1. Contexto</a></li>
#         <li><a href="#">1.2. Desarrollo</a></li>
#         <li><a href="#d">1.3. Conclusiones</a></li>
#     </ul>
#     <li><a href="#">2. Informe Científico</a></li>
#     <ul>
#         <li><a href="#">2.1. Configuración </a></li>
#         <li><a href="#">2.2. Carga de datos </a></li>
#         <li><a href="#">2.3. Preprocesamiento de datos</a></li>
#         <li><a href="#">2.4. Hipótesis</a></li>
#         <li><a href="#">2.5. Visualización y resultados intermedios</a></li>
#         <li><a href="#">2.6. Salidas/Resultados </a></li>
#         <li><a href="#">2.7. Consluciones, recomendaciones y líneas futuras</a></li>
#     </ul>
# </ul>
#
# ---

# %% [markdown]
# ### Instrucciones para la ejecución de este notebook
# _Indicar brevemente si existen instrucciones especiales para la correcta ejecución de este notebook. E.g.: El presente informe contiene código ejecutable de los modelos desarrollados para el caso digital. Se recomienda seguir el orden establecido para la ejecución de los bloques de código para evitar posibles conflictos entre variables (aunque se ha tratado de definir variables distintas en cada bloque para evitar este escenario)._

# %% [markdown]
# ---

# %% [markdown]
# # Resumen Ejecutivo

# %% [markdown]
# *Resumen ejecutivo con la descripción del caso desde un punto de vista de negocio, incluyendo el contexto, la figura principal (imagen/gráfico que resuma  los resultados obtenidos) y las conclusiones o recomendaciones*

# %% [markdown]
# ## Contexto

# %% [markdown]
# - *Contexto del caso. Identificar y explicar de forma sucinta:*
#     - *Tipo de problema analítico que se aborda: análisis prescriptivo, análisis diagnóstico, análisis predictivo, análisis prescriptivo.*
#     - *Soluciones analíticas que abordan el problema*
# - *Métricas de impacto en el negocio*
# - *Métricas de modelos*

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# *Breve resumen de los resultados obtenidos (esquemas, imágenes...)*

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# *Principales conclusiones aquí*

# %% [markdown]
# ----

# %% [markdown]
# # Informe Científico

# %% [markdown]
# ## Configuracion

# %% [markdown]
# - *Imports necesarios y Carga de funciones desde scripts (src/)*
# - *Configuración de entorno o rutas.*

# %%
# Añade la carpeta raiz al path
import sys

sys.path.insert(0, "../")
# Permite actualizar librerias sin tener que reiniciar kernel
# %load_ext autoreload
# %autoreload 2

# %%
# Código aquí

# %% [markdown]
# ## Carga de los datos

# %% [markdown]
# *Describir las distintas fuentes de datos utilizadas, así como la naturaleza de los mismos. Incluyendo al menos el periodo de observación, el tipo de dato y su significado desde el punto de vista de negocio.*

# %%
# Código aquí

# %% [markdown]
# ## Preprocesamiento de datos

# %% [markdown]
# *Describir las distintas transformaciones y filtros que hayan sido realizadas a los datos originales con el objetivo de poder aplicarlos a los distintos modelos analítico.*

# %%
# Código aquí

# %% [markdown]
# ## Hipótesis

# %% [markdown]
# - *¿Qué se quiere comprobar o analizar?*
# - *Hipótesis concretas que se ponen a prueba con esta tarea.*
# - *Si no hay hipótesis como tal, explicar el propósito del análisis.*

# %% [markdown]
# ## Visualizaciones y resultados intermedios

# %% [markdown]
# *Presentan los principales gráficos, tablas o métricas que permiten interpretar los resultados obtenidos a partir de los datos transformados.*
#
# *Se deben incluir visualizaciones que ayuden a:*
# - *Comprobar o refutar las hipótesis planteadas.*
# - *Comparar grupos, comportamientos o distribuciones.*
# - *Detectar patrones, anomalías o relaciones relevantes.*
# - *Justificar decisiones tomadas en el análisis.*
#
# *Además, se espera:*
# - *Acompañar cada gráfico o tabla con una breve interpretación (no solo mostrar).*
# - *Explicar qué criterio se sigue para considerar un resultado válido, relevante o descartable*
# - *Señalar posibles limitaciones del análisis en caso de ambigüedad o ruido en los datos.*
#
# *Esta sección debe aportar evidencia clara que sustente las conclusiones del notebook.*

# %%
# Código aquí

# %% [markdown]
# ## Salidas/resultados

# %% [markdown]
# - *Generación de outputs relevantes: gráficos, métricas, archivos, objetos.*
# - *Exportación de resultados o guardado en formato deseado (parquet, pickle, csv...).*

# %%
# Código aquí

# %% [markdown]
# ## Conclusiones, recomendaciones y líneas futuras

# %% [markdown]
# *Especificar cuáles son las conclusiones, las recomendaciones y las posibles líneas futuras o que no se han explorado.*
